# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import requests
import os
from selenium import webdriver

# %%
baseurl = 'https://www.nasdaq.com/market-activity/commodities/lbs/historical'
driver = webdriver.Safari()
response = driver.get(baseurl)
soup = bs(driver.page_source, 'html')

#soup = bs(page_html)

#link_list = list()

# #for link in soup.find(class_='col-lg-4 col-xl-4 col-md-6').find_all('a'):
# for listl in soup.find_all(class_='col-lg-4 col-xl-4 col-md-6'):
#     for link in listl.find_all('a'):    
#         link_list.append("https://www.ratebeer.com" + link['href'])
        
#print (soup)
# Out:
# <html class="js" dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# "><head><script async="" src="https://static.criteo.net/js/ld/publishertag.prebid.117.js" type="text/javascript"></script><script async="" src="https://www.clarity.ms/eus-d/s/0.6.36/clarity.js"></script><script src="https://pagead2.googlesyndication.com/pagead/managed/js/adsense/m202207260101/reactive_library_fy2021.js?bust=31068639"></script><script async="" src="https://www.clarity.ms/tag/uet/17348885"></script><script async="" src="https://www.clarity.ms/tag/uet/16005587"></script><script async="" src="https://www.clarity.ms/tag/uet/17370908"></script><script async="" src="https://analytics.tiktok.com/i18n/pixel/config.js?sdkid=C9KLRGBC77UD01Q8H9D0&amp;hostname=www.nasdaq.com" type="text/javascript"></script><script async="" src="https://cdn.bizible.com/xdc.js?_biz_u=2e50323337084894f77ed460675c0412&amp;_biz_h=802059049&amp;cdn_o=a&amp;jsVer=4.22.07.28" type="text/javascript"></script>
# <meta charset="utf-8"/>
# </head><body><iframe role="presentation" src="javascript:void(0)" style="width: 0px; height: 0px; border: 0px; display: none;" title=""></iframe><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://analytics.tiktok.com/i18n/pixel/events.js?sdkid=C9KLRGBC77UD01Q8H9D0&amp;lib=ttq" type="text/javascript"></script><script async="" src="https://connect.facebook.net/signals/config/713864198683614?v=2.9.69&amp;r=stable"></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script async="" src="https://www.redditstatic.com/ads/pixel.js" type="text/javascript"></script><script async="" src="https://www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="https://bat.bing.com/bat.js" type="text/javascript"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js" type="text/javascript"></script><script async="" src="https://static.ads-twitter.com/uwt.js" type="text/javascript"></script><script async="" gtm="GTM-TB9QCTB" src="https://www.google-analytics.com/gtm/optimize.js?id=GTM-NFN87FQ" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-4VZJSZ76VC&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script src="https://partner.googleadservices.com/gampad/cookie.js?domain=www.nasdaq.com&amp;callback=_gfp_s_&amp;client=ca-pub-1861191755926748&amp;gpid_exp=1"></script><script id="#livevalidationscript" src="https://img04.en25.com/i/livevalidation_standalone.compressed.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-TB9QCTB&amp;gtm_auth=AbgJsDZWx9ClJu0CVnQWXA&amp;gtm_preview=env-10&amp;gtm_cookies_win=x"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://c.aaxads.com/aax.js?pub=AAX8M81YB&amp;hst=www.nasdaq.com&amp;ver=1.2" type="text/javascript"></script><script id="google_shimpl" src="https://pagead2.googlesyndication.com/pagead/managed/js/adsense/m202207260101/show_ads_impl_fy2019.js?bust=31068639"></script><script async="" src="//c.amazon-adsystem.com/aax2/apstag.js"></script><script async="" data-ad-client="ca-pub-1861191755926748" data-checked-head="true" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js" type="text/javascript"></script><script async="" src="https://ad.wsod.com/site/2caa62b3a3a0755e2cda9deea9070934/0.0.async/" type="text/javascript"></script><script async="" src="//ads.pubmatic.com/AdServer/js/pwt/159924/3565/pwt.js" type="text/javascript"></script><script>window.digitalData = {"pageInstanceID":"production:home:market-activity:commodities:lbs:historical","page":{"pageInfo":{"author":null,"breadcrumbs":["home","market-activity","commodities","lbs","historical"],"destinationURL":"https:\/\/www.nasdaq.com\/market-activity\/commodities\/lbs\/historical","entryURL":null,"lang":"en","onsiteSearchResults":null,"onsiteSearchTerm":null,"pageID":"home:market-activity:commodities:lbs:historical","pageName":"historical","pagePathLevel1":"market-activity","pagePathLevel2":"market-activity:commodities","pagePathLevel3":"market-activity:commodities:lbs","pagePathLevel4":"market-activity:commodities:lbs:historical","pagePathLevel5":null,"publisher":null,"referringURL":null,"sysEnv":null,"timeStamp":1659171618,"refreshDisable":false,"disableVideoAds":false,"customPageName":null,"sponsoredContent":false,"nativeRefreshDisable":[],"platform":"rrp"},"category":{"eventType":null,"pageType":"symbol-page","videoType":null,"primaryCategory":"market-activity","subCategory":"commodities"},"attributes":{"adDisplay":false,"assetClass":["commodities"],"businessUnit":null,"campaignParameters":null,"industry":null,"quoteSymbol":["LBS"],"region":null,"sponsored":false,"topic":null,"audience":null,"glossaryTerm":null}},"user":[{"segment":{"loginStatus":"guest","registra ...
# <script defer="" src="https://www.nasdaq.com/sites/acquia.prod/files/google_tag/nasdaq_gtm/google_tag.script.js?rfrk10"></script>
# <meta content="Lumber (LBS) Historical Price Data | Nasdaq" name="title"/>
# <link href="https://www.nasdaq.com/market-activity/commodities/lbs/historical" hreflang="en" rel="alternate"/>
# <link href="https://www.nasdaq.com/de/market-activity/commodities/lbs/historical" hreflang="de" rel="alternate"/>
# <link href="https://www.nasdaq.com/es/market-activity/commodities/lbs/historical" hreflang="es" rel="alternate"/>
# <link href="https://www.nasdaq.com/fr/market-activity/commodities/lbs/historical" hreflang="fr" rel="alternate"/>
# <link href="https://www.nasdaq.com/it/market-activity/commodities/lbs/historical" hreflang="it" rel="alternate"/>
# <link href="https://www.nasdaq.com/zh/market-activity/commodities/lbs/historical" hreflang="zh" rel="alternate"/>
# <link href="https://www.nasdaq.com/market-activity/commodities/lbs/historical" hreflang="x-default" rel="alternate"/>
# <link href="https://www.nasdaq.com/market-activity/commodities/lbs/historical" rel="canonical"/>
# <meta content="https://www.nasdaq.com/market-activity/commodities/lbs/historical" property="og:url"/>
# <meta content="Lumber (LBS) Historical Price Data" property="title"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@Nasdaq" name="twitter:site"/>
# <meta content="symbol-page" name="com.nasdaq.cms.taxonomy.pageType"/>
# <meta content="LBS" name="com.nasdaq.cms.taxonomy.quoteSymbol"/>
# <meta content="LBS" name="com.nasdaq.cms.taxonomy.quoteSymbol"/>
# <meta content="commodities" name="com.nasdaq.cms.taxonomy.assetClass"/>
# <meta content="" name="com.nasdaq.cms.taxonomy.region"/>
# <meta content="Lumber (LBS) Historical Prices - Nasdaq offers historical prices &amp; market activity data for US and global markets." name="description"/>
# <meta content="Drupal 9 (https://www.drupal.org)" name="Generator"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="" name="storyType"/>
# <script type="application/ld+json">{
#     "@context": "https://schema.org",
#     "@graph": [
#         {
#             "@type": "Corporation",
#             "@id": "https://www.nasdaq.com/",
#             "name": "Nasdaq",
#             "url": "https://www.nasdaq.com/",
#             "logo": {
#                 "@type": "ImageObject",
#                 "url": "https://www.nasdaq.com/themes/nsdq/dist/assets/images/logo-half-white.svg"
#             }
#         },
#         {
#             "@type": "WebPage",
#             "breadcrumb": {
#                 "@type": "BreadcrumbList",
#                 "itemListElement": [
#                     {
#                         "@type": "ListItem",
#                         "position": 1,
#                         "name": "Home",
#                         "item": "https://www.nasdaq.com/"
#                     },
#                     {
#                         "@type": "ListItem",
#                         "position": 2,
#                         "name": "Market Activity",
#                         "item": "https://www.nasdaq.com/market-activity"
#                     },
#                     {
#                         "@type": "ListItem",
#                         "position": 3,
#                         "name": "Commodities",
#                         "item": "https://www.nasdaq.com/market-activity/commodities"
#                     },
#                     {
#                         "@type": "ListItem",
#                         "position": 4,
#                         "name": "LBS",
#                         "item": "https://www.nasdaq.com/market-activity/commodities/lbs"
#                     }
#                 ]
#             }
#         },
#         {
#             "@type": "WebSite",
#             "name": "Nasdaq",
#             "url": "https://www.nasdaq.com/",
#             "potentialAction": {
#                 "@type": "SearchAction",
#                 "target": "https://www.nasdaq.com/search?q={search_term_string}",
#                 "query-input": "required name=search_term_string"
#             }
#         }
#     ]
# }</script>
# <!-- Load the Prebid Magnite JavaScript Library -->
# <script async="" src="//securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script async="" src="//micro.rubiconproject.com/prebid/dynamic/22692.js?Nasdaq_Page_Template=symbol-page&amp;Nasdaq_Page_Name=historical"></script>
# <!-- Identity Hub -->
# <script type="text/javascript">
# (function() {
# 	var purl = window.location.href;
# 	var url = '//ads.pubmatic.com/AdServer/js/pwt/159924/3565';
# 	var profileVersionId = '';
# 	if(purl.indexOf('pwtv=')>0){
# 		var regexp = /pwtv=(.*?)(&|$)/g;
# 		var matches = regexp.exec(purl);
# 		if(matches.length >= 2 && matches[1].length > 0){
# 			profileVersionId = '/'+matches[1];
# 		}
# 	}
# 	var wtads = document.createElement('script');
# 	wtads.async = true;
# 	wtads.type = 'text/javascript';
# 	wtads.src = url+profileVersionId+'/pwt.js';
# 	var node = document.getElementsByTagName('script')[0];
# 	node.parentNode.insertBefore(wtads, node);
# })();
# </script>
# <script type="text/javascript">
# (function () {
#  function loadScript(tagSrc,client) {
#  var scriptTag = document.createElement('script'),
#  placeTag = document.getElementsByTagName("script")[0];
#  scriptTag.async = true;
#  scriptTag.type = "text/javascript";
#  scriptTag.src = tagSrc;
#  if (client !== null) {
#  scriptTag.setAttribute('data-ad-client', client);
#  }
#  placeTag.parentNode.insertBefore(scriptTag, placeTag);
#  }
#  var smartSrc = "https://ad.wsod.com/site/2caa62b3a3a0755e2cda9deea9070934/0.0.async/";
#  var autoSrc = "https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js";
#  var client = "ca-pub-1861191755926748";
# // Load the Smart Targets script
# loadScript(smartSrc,null);
#  if (window.digitalData.page.category.pageType != 'article-page') {
#    // Load Google Auto Ads script
#    loadScript(autoSrc,client);
#  }
#  })();
#  </script>
# <script type="text/javascript">
# // Initialize the prebid variables.
# var pbjs = pbjs || {};
# pbjs.que = pbjs.que || [];
#
# // Initialize the google variables.
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# // Add a place to store the slot name variable.
# googletag.slots = googletag.slots || {};
# // Add a place to store slots that are queued/observed
# // These are slots that we already stored but waiting to be fetched
# googletag.slotsQueued = googletag.slotsQueued || {};
#
# window.adsList = window.adsList || [];
# </script>
# <script type="text/javascript">
# //Load the APS JavaScript Library
# !function(a9,a,p,s,t,A,g){
#    if(a[a9])return;
#    function q(c,r){a[a9]._Q.push([c,r])}
#    a[a9]={
#       init:function(){q("i",arguments)},
#       fetchBids:function(){q("f",arguments)},
#       setDisplayBids:function(){},
#       targetingKeys:function(){return[]},_Q:[]
#    };
#       A=p.createElement(s);
#       A.async=!0;
#       A.src=t;
#       g=p.getElementsByTagName(s)[0];
#       g.parentNode.insertBefore(A,g)
#    }("apstag",window,document,"script","//c.amazon-adsystem.com/aax2/apstag.js");
#
# //Initialize the Library
# apstag.init({
#     pubID: '3444',
#     adServer: 'googletag',
#     bidTimeout: 800,
#     deals: true
# });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-e5s",
#     name: "/3244/market-activity__commodities/ATF_Leaderboard",
#     size: [[320, 50], [728, 90], [970, 250]] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [320, 50])
#                   .addSize([768, 0], [728, 90])
#                   .addSize([1200, 0], [[728, 90], [970, 250]])
#                 .build();
#
#     googletag.slots["js-dfp-tag-e5s"] = googletag.defineSlot("/3244/market-activity__commodities/ATF_Leaderboard", [[320, 50], [728, 90], [970, 250]], "js-dfp-tag-e5s")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag--pc",
#     name: "/3244/market-activity__commodities/ATF_RightRailBox",
#     size: [[300, 250], [300, 600]] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([1200, 0], [[300, 250], [300, 600]])
#                   .addSize([0, 0], [])
#                 .build();
#
#     googletag.slots["js-dfp-tag--pc"] = googletag.defineSlot("/3244/market-activity__commodities/ATF_RightRailBox", [[300, 250], [300, 600]], "js-dfp-tag--pc")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-J08",
#     name: "/3244/market-activity__commodities/ATF_FindASymbolRight_1",
#     size: [120, 60] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([1200, 0], [120, 60])
#                 .build();
#
#     googletag.slots["js-dfp-tag-J08"] = googletag.defineSlot("/3244/market-activity__commodities/ATF_FindASymbolRight_1", [120, 60], "js-dfp-tag-J08")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-H0A",
#     name: "/3244/market-activity__commodities/ATF_FindASymbolLeft_2",
#     size: [120, 60] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([1200, 0], [120, 60])
#                 .build();
#
#     googletag.slots["js-dfp-tag-H0A"] = googletag.defineSlot("/3244/market-activity__commodities/ATF_FindASymbolLeft_2", [120, 60], "js-dfp-tag-H0A")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-snU",
#     name: "/3244/market-activity__commodities/ATF_FindASymbolRight_2",
#     size: [120, 60] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([1200, 0], [120, 60])
#                 .build();
#
#     googletag.slots["js-dfp-tag-snU"] = googletag.defineSlot("/3244/market-activity__commodities/ATF_FindASymbolRight_2", [120, 60], "js-dfp-tag-snU")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-eBM",
#     name: "/3244/market-activity__commodities/ATF_FindASymbolLeft_1",
#     size: [120, 60] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([1200, 0], [120, 60])
#                 .build();
#
#     googletag.slots["js-dfp-tag-eBM"] = googletag.defineSlot("/3244/market-activity__commodities/ATF_FindASymbolLeft_1", [120, 60], "js-dfp-tag-eBM")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-H-Y",
#     name: "/3244/market-activity__commodities/ATF_QuoteNavigationButton",
#     size: [120, 60] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([1200, 0], [120, 60])
#                 .build();
#
#     googletag.slots["js-dfp-tag-H-Y"] = googletag.defineSlot("/3244/market-activity__commodities/ATF_QuoteNavigationButton", [120, 60], "js-dfp-tag-H-Y")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-ORU",
#     name: "/3244/market-activity__commodities/ATF_Native",
#     size: 'fluid' // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#
#     googletag.slots["js-dfp-tag-ORU"] = googletag.defineSlot("/3244/market-activity__commodities/ATF_Native", 'fluid', "js-dfp-tag-ORU")
#
#         .addService(googletag.pubads())
#
#
#
#
#             ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-_VE",
#     name: "/3244/market-activity__commodities/BTF_RightRailBox_1",
#     size: [[300, 250], [300, 600]] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([1200, 0], [[300, 250], [300, 600]])
#                   .addSize([0, 0], [])
#                 .build();
#
#     googletag.slots["js-dfp-tag-_VE"] = googletag.defineSlot("/3244/market-activity__commodities/BTF_RightRailBox_1", [[300, 250], [300, 600]], "js-dfp-tag-_VE")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-oaU",
#     name: "/3244/market-activity__commodities/BTF_Leaderboard_Desktop_Only",
#     size: [[300, 250], [728, 90], [970, 250], [1200, 460]] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [])
#                   .addSize([1200, 0], [[300, 250], [728, 90], [970, 250], [1200, 460]])
#                 .build();
#
#     googletag.slots["js-dfp-tag-oaU"] = googletag.defineSlot("/3244/market-activity__commodities/BTF_Leaderboard_Desktop_Only", [[300, 250], [728, 90], [970, 250], [1200, 460]], "js-dfp-tag-oaU")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-2E8",
#     name: "/3244/market-activity__commodities/BTF_Leaderboard_Mobile_Tablet",
#     size: [[300, 250], [300, 600], [336, 280], [728, 90], [728, 460]] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [[300, 250], [300, 600], [336, 280]])
#                   .addSize([768, 0], [[728, 90], [728, 460]])
#                   .addSize([1200, 0], [])
#                 .build();
#
#     googletag.slots["js-dfp-tag-2E8"] = googletag.defineSlot("/3244/market-activity__commodities/BTF_Leaderboard_Mobile_Tablet", [[300, 250], [300, 600], [336, 280], [728, 90], [728, 460]], "js-dfp-tag-2E8")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-iVQ",
#     name: "/3244/market-activity__commodities/BTF_FeaturedSymbol3Up_1",
#     size: [120, 60] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [])
#                   .addSize([1200, 0], [120, 60])
#                 .build();
#
#     googletag.slots["js-dfp-tag-iVQ"] = googletag.defineSlot("/3244/market-activity__commodities/BTF_FeaturedSymbol3Up_1", [120, 60], "js-dfp-tag-iVQ")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-RVM",
#     name: "/3244/market-activity__commodities/BTF_FeaturedSymbol3Up_2",
#     size: [120, 60] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [])
#                   .addSize([1200, 0], [120, 60])
#                 .build();
#
#     googletag.slots["js-dfp-tag-RVM"] = googletag.defineSlot("/3244/market-activity__commodities/BTF_FeaturedSymbol3Up_2", [120, 60], "js-dfp-tag-RVM")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-2BA",
#     name: "/3244/Watchlist/MyQuotesButton",
#     size: [120, 60] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([768, 0], [120, 60])
#                 .build();
#
#     googletag.slots["js-dfp-tag-2BA"] = googletag.defineSlot("/3244/Watchlist/MyQuotesButton", [120, 60], "js-dfp-tag-2BA")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-cVQ",
#     name: "/3244/Watchlist/WatchlistButton_1",
#     size: [120, 60] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([768, 0], [120, 60])
#                 .build();
#
#     googletag.slots["js-dfp-tag-cVQ"] = googletag.defineSlot("/3244/Watchlist/WatchlistButton_1", [120, 60], "js-dfp-tag-cVQ")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-89I",
#     name: "/3244/Watchlist/MyQuotesButton2",
#     size: [120, 60] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([768, 0], [120, 60])
#                 .build();
#
#     googletag.slots["js-dfp-tag-89I"] = googletag.defineSlot("/3244/Watchlist/MyQuotesButton2", [120, 60], "js-dfp-tag-89I")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-Ltk",
#     name: "/3244/market-activity__commodities/ATF_RightRail2UpButton_QSD",
#     size: [120, 60] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([1200, 0], [120, 60])
#                 .build();
#
#     googletag.slots["js-dfp-tag-Ltk"] = googletag.defineSlot("/3244/market-activity__commodities/ATF_RightRail2UpButton_QSD", [120, 60], "js-dfp-tag-Ltk")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# googletag.cmd.push(function() {
#       googletag.pubads().enableAsyncRendering();
#         googletag.pubads().enableSingleRequest();
#           googletag.pubads().disableInitialLoad();
#       //Pulling the ad sizes from URL for testing the ad sizes
#   function test_check(){
#     if (window.location.href.indexOf("test") >= 0) {
#       var vars = window.location.href.split('?');
#       for (i in vars){
#         if (vars[i].indexOf("test") >= 0){
#           return [vars[i].split('=')[1]]
#         }
#       }}
#     return [""]
#   }
#   // GET Cookie code for making ad targeting easier
#   var reRegExpChar = /[\\^$.*+?()[\]{}|]/g,
#   reHasRegExpChar = RegExp(reRegExpChar.source);
#   function escapeRegExp(string) {
#     return string && reHasRegExpChar.test(string) ? string.replace(reRegExpChar, '\\$&') : string;
#   }
#   function getCookie(name) {
#     var k = escapeRegExp(name);
#     var v = document.cookie.match('(^|;) ?' + k + '=([^;]*)(;|$)');
#     return v ? v[2] : null;
#   }
#   function setCookie(name, value, days) {
#     const d = new Date();
#     d.setTime(d.getTime() + 24 * 60 * 60 * 1000 * days);
#     // eslint-disable-next-line prefer-template
#     document.cookie = name + '=' + value + ';path=/;expires=' + d.toGMTString() + ';domain=.nasdaq.com';
#   }
#   function initRecentlyViewedTracking() {
#     // Get recently viewed cookie and populate data variables
#     var recentlyViewedCookie = getCookie('recentlyViewedList');
#     if (recentlyViewedCookie && recentlyViewedCookie !== 'false') {
#       var recentlyViewedCookieArray = recentlyViewedCookie.split(',').reverse();
#       return recentlyViewedCookieArray;
#     }
#     else {
#       return '';
#     }
#   }
#   function initVolatilityTracking() {
#     var volatileCookie = getCookie('volatileMarket');
#     if (!volatileCookie) {
#       Promise.all([
#         fetch('https://api.nasdaq.com/api/quote/indices?symbol=indu'),
#         fetch('https://api.nasdaq.com/api/quote/indices?symbol=ndx'),
#         fetch('https://api.nasdaq.com/api/quote/indices?symbol=comp'),
#         fetch('https://api.nasdaq.com/api/quote/indices?symbol=rut'),
#         fetch('https://api.nasdaq.com/api/quote/indices?symbol=spx')
#       ]).then(function (responses) {
#         // Get a JSON object from each of the responses
#         return Promise.all(responses.map(function (response) {
#           return response.json();
#         }));
#       }).then(function (data) {
#         // Grab percentage change from each index
#         var indu = parseFloat(data[0].data[0].percentageChange);
#         var ndx = parseFloat(data[1].data[0].percentageChange);
#         var comp = parseFloat(data[2].data[0].percentageChange);
#         var rut = parseFloat(data[3].data[0].percentageChange);
#         var spx = parseFloat(data[4].data[0].percentageChange);
#         // Check if any are up/down more than 0.5%, if so then set the cookie and set ad targeting
#         if (((indu || ndx || comp || rut || spx) > 0.5) || ((indu || ndx || comp || rut || spx) < -0.5)) {
#           setCookie('volatileMarket', true, 1);
#           return 'true';
#         }
#       }).catch(function (error) {
#         // if there's an error
#       });
#     } else {
#       // Already a violatile market so just set ad targeting
#       return 'true';
#     }
#   }
#   setTimeout(function () {
#     if (typeof drupalSettings != "undefined") {
#       var uid = drupalSettings.user.uid;
#       var watchlist_symbols = {
#           "async": false,
#           "crossDomain": true,
#           "url": "/api/v1/watchlist/" + uid,
#           "method": "GET",
#           "headers": {
#           "content-Type" : "application/x-www-form-urlencoded",
#         }
#       }
#       if (uid != 0) { // User is signed in and has ID, pass Watchlist Symbols and Any Tipranks portfolio personal info to target
#         window.jQuery.ajax(watchlist_symbols).then(function(responseText) {
#           googletag.pubads().setTargeting("nasdaqdotcom_watchlist_symbol_list", responseText.watchlist);
#         });
#         var portfolioProfessionCookie = getCookie('portfolioProfession');
#         var portfolioAnnualIncomeCookie = getCookie('portfolioAnnualIncome');
#         var portfolioAgeCookie = getCookie('portfolioAge');
#         if (portfolioProfessionCookie) {
#           googletag.pubads().setTargeting("nasdaqdotcom_portfolio_profession", portfolioProfessionCookie);
#         }
#         if (portfolioAnnualIncomeCookie) {
#           googletag.pubads().setTargeting("nasdaqdotcom_portfolio_annual_income", portfolioAnnualIncomeCookie);
#         }
#         if (portfolioAgeCookie) {
#           googletag.pubads().setTargeting("nasdaqdotcom_portfolio_age", portfolioAgeCookie);
#         }
#       }
#     }
#   }, 2000);
#   googletag.pubads().setTargeting("nasdaqdotcom_page_instance_id", digitalData.pageInstanceID || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_page_template", digitalData.page.category.pageType || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_publisher", digitalData.page.pageInfo.publisher || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_page_name", digitalData.page.pageInfo.pageName || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_search_term", digitalData.page.pageInfo.onsiteSearchTerm || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_region_tag_list", (digitalData.page.attributes.region || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_topic_tag_list", (digitalData.page.attributes.topic || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_asset_class_tag_list", (digitalData.page.attributes.assetClass || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_quote_symbol_list", (digitalData.page.attributes.quoteSymbol || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_industry_tag_list", (digitalData.page.attributes.industry || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_audience_tag_lists", (digitalData.page.attributes.audience || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_recently_viewed_symbol_list", initRecentlyViewedTracking());
#   googletag.pubads().setTargeting("nasdaqdotcom_volatile_market", initVolatilityTracking());
#   googletag.pubads().setTargeting("nasdaqdotcom_video_type", digitalData.page.category.videoType || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_event_type", digitalData.page.category.eventType || '');
#   googletag.pubads().setTargeting("test",test_check());
#
#
#   googletag.enableServices();
# });
# </script>
# <link href="https://www.nasdaq.com/sites/acquia.prod/files/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <title>Lumber (LBS) Historical Price Data | Nasdaq</title>
# <link href="https://www.nasdaq.com/sites/acquia.prod/files/css/css_l4-xkrP9cCYlKvl_zslf4Y_KUQ9tbccvWQ2r6wpzqYk.css" media="all" rel="stylesheet"/>
# <link href="https://www.nasdaq.com/sites/acquia.prod/files/css/css_CPRX4bII43_8xcD4wsPImHNWwb0Hi9VRRkJW-gxEID4.css" media="all" rel="stylesheet"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/manifest.json" rel="manifest"/>
# <link as="font" crossorigin="anonymous" href="https://fonts.gstatic.com/s/sourcesanspro/v13/6xKydSBYKcSV-LCoeQqfX1RYOo3ik4zwlxdu3cOWxw.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://fonts.gstatic.com/s/sourcesanspro/v13/6xKydSBYKcSV-LCoeQqfX1RYOo3i54rwlxdu3cOWxw.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://fonts.gstatic.com/s/sourcesanspro/v13/6xK3dSBYKcSV-LCoeQqfX1RYOo3qOK7lujVj9w.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://use.typekit.net/af/150b2d/00000000000000003b9afb65/27/l?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&amp;fvd=n1&amp;v=3" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://use.typekit.net/af/7efd4b/00000000000000003b9afb67/27/l?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&amp;fvd=n3&amp;v=3" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://use.typekit.net/af/4e2d77/00000000000000003b9afb6b/27/l?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&amp;fvd=n6&amp;v=3" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://www.nasdaq.com/themes/nsdq/dist/assets/fonts/Roboto-Regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://www.nasdaq.com/themes/nsdq/dist/assets/fonts/Roboto-Light.woff" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="anonymous" href="https://www.nasdaq.com/themes/nsdq/dist/assets/fonts/Roboto-Bold.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://www.nasdaq.com/themes/nsdq/dist/assets/fonts/Roboto-Medium.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://www.nasdaq.com/themes/nsdq/dist/assets/fonts/nasdaq-icons.ttf?ck9pto" rel="preload" type="font/ttf"/>
# <link as="style" href="https://nd.nasdaq.com/js/forms2/css/forms2.css" rel="preload"/>
# <link as="style" href="https://nd.nasdaq.com/js/forms2/css/forms2-theme-plain.css" rel="preload"/> <link href="https://www.googleadservices.com" rel="dns-prefetch"/>
# <link href="https://micro.rubiconproject.com" rel="dns-prefetch"/>
# <link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <meta content="#da532c" name="msapplication-TileColor"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="A4ZdzztVttv1nCpL1SePVC3K2K" name="google-site-verification"/>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-106577912-1"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){window.dataLayer.push(arguments);}  gtag('js', new Date());  gtag('config', 'UA-106577912-1', { 'send_page_view': false });
#     </script>
# <link href="" rel="dns-prefetch"/>
# <script src="https://cdn.jwplayer.com/libraries/OgpraAEe.js"></script>
# <meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><script async="" src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_2022072502.js?cb=31068699"></script><script async="async" src="//ad.wsod.com/site/2caa62b3a3a0755e2cda9deea9070934/1.0.async/1659209763;0,0,0;1920x1080x1;https%3A_@2F_@2Fwww.nasdaq.com_@2Fmarket-activity_@2Fcommodities_@2Flbs_@2Fhistorical;;;" type="text/javascript"></script><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><script src="//ats.rlcdn.com/ats.js"></script><script src="//secure.cdn.fastclick.net/js/pubcid/latest/pubcid.min.js"></script><script src="//cdn.id5-sync.com/api/1.0/id5-api.js"></script><link as="script" href="https://adservice.google.com/adsid/integrator.js?domain=www.nasdaq.com" rel="preload"/><script src="https://adservice.google.com/adsid/integrator.js?domain=www.nasdaq.com" type="text/javascript"></script><meta content="" http-equiv="origin-trial"/><script async="" src="https://static.hotjar.com/c/hotjar-1904744.js?sv=6"></script><script id="addWebPageUrl">MktoForms2.whenReady(function(form) {form.addHiddenFields({'webPageURL':'https://www.nasdaq.com/market-activity/commodities/lbs/historical'}); form.submittable(true); });</script><script async="" data-ueto="ueto_db53cc0680" src="https://bat.bing.com/p/action/17370908.js" type="text/javascript"></script><script async="" data-ueto="ueto_97df5310c7" src="https://bat.bing.com/p/action/16005587.js" type="text/javascript"></script><script async="" data-ueto="ueto_742bb679e5" src="https://bat.bing.com/p/action/17348885.js" type="text/javascript"></script><script async="" charset="utf-8" src="https://script.hotjar.com/modules.311bafb9406f6ba6bebc.js"></script><style type="text/css">iframe#_hjRemoteVarsFrame {display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;}</style><script async="" src="https://googleads.g.doub ...
# #onetrust-banner-sdk,#onetrust-pc-sdk,#ot-sdk-cookie-policy,#ot-sync-ntfy{font-size:16px}#onetrust-banner-sdk *,#onetrust-banner-sdk ::after,#onetrust-banner-sdk ::before,#onetrust-pc-sdk *,#onetrust-pc-sdk ::after,#onetrust-pc-sdk ::before,#ot-sdk-cookie-policy *,#ot-sdk-cookie-policy ::after,#ot-sdk-cookie-policy ::before,#ot-sync-ntfy *,#ot-sync-ntfy ::after,#ot-sync-ntfy ::before{-webkit-box-sizing:content-box;-moz-box-sizing:content-box;box-sizing:content-box}#onetrust-banner-sdk div,#onetrust-banner-sdk span,#onetrust-banner-sdk h1,#onetrust-banner-sdk h2,#onetrust-banner-sdk h3,#onetrust-banner-sdk h4,#onetrust-banner-sdk h5,#onetrust-banner-sdk h6,#onetrust-banner-sdk p,#onetrust-banner-sdk img,#onetrust-banner-sdk svg,#onetrust-banner-sdk button,#onetrust-banner-sdk section,#onetrust-banner-sdk a,#onetrust-banner-sdk label,#onetrust-banner-sdk input,#onetrust-banner-sdk ul,#onetrust-banner-sdk li,#onetrust-banner-sdk nav,#onetrust-banner-sdk table,#onetrust-banner-sdk thead,#onetrust-banner-sdk tr,#onetrust-banner-sdk td,#onetrust-banner-sdk tbody,#onetrust-banner-sdk .ot-main-content,#onetrust-banner-sdk .ot-toggle,#onetrust-banner-sdk #ot-content,#onetrust-banner-sdk #ot-pc-content,#onetrust-banner-sdk .checkbox,#onetrust-pc-sdk div,#onetrust-pc-sdk span,#onetrust-pc-sdk h1,#onetrust-pc-sdk h2,#onetrust-pc-sdk h3,#onetrust-pc-sdk h4,#onetrust-pc-sdk h5,#onetrust-pc-sdk h6,#onetrust-pc-sdk p,#onetrust-pc-sdk img,#onetrust-pc-sdk svg,#onetrust-pc-sdk button,#onetrust-pc-sdk section,#onetrust-pc-sdk a,#onetrust-pc-sdk label,#onetrust-pc-sdk input,#onetrust-pc-sdk ul,#onetrust-pc-sdk li,#onetrust-pc-sdk nav,#onetrust-pc-sdk table,#onetrust-pc-sdk thead,#onetrust-pc-sdk tr,#onetrust-pc-sdk td,#onetrust-pc-sdk tbody,#onetrust-pc-sdk .ot-main-content,#onetrust-pc-sdk .ot-toggle,#onetrust-pc-sdk #ot-content,#onetrust-pc-sdk #ot-pc-content,#onetrust-pc-sdk .checkbox,#ot-sdk-cookie-policy div,#ot-sdk-cookie-policy span,#ot-sdk-cookie-policy h1,#ot-sdk-cookie-policy h2,#ot-sdk-cookie-policy h3,#ot-sdk-cookie-policy h4,#ot-sdk-cookie-policy h5,#ot-sdk-cookie-policy h6,#ot-sdk-cookie-policy p,#ot-sdk-cookie-policy img,#ot-sdk-cookie-policy svg,#ot-sdk-cookie-policy button,#ot-sdk-cookie-policy section,#ot-sdk-cookie-policy a,#ot-sdk-cookie-policy label,#ot-sdk-cookie-policy input,#ot-sdk-cookie-policy ul,#ot-sdk-cookie-policy li,#ot-sdk-cookie-policy nav,#ot-sdk-cookie-policy table,#ot-sdk-cookie-policy thead,#ot-sdk-cookie-policy tr,#ot-sdk-cookie-policy td,#ot-sdk-cookie-policy tbody,#ot-sdk-cookie-policy .ot-main-content,#ot-sdk-cookie-policy .ot-toggle,#ot-sdk-cookie-policy #ot-content,#ot-sdk-cookie-policy #ot-pc-content,#ot-sdk-cookie-policy .checkbox,#ot-sync-ntfy div,#ot-sync-ntfy span,#ot-sync-ntfy h1,#ot-sync-ntfy h2,#ot-sync-ntfy h3,#ot-sync-ntfy h4,#ot-sync-ntfy h5,#ot-sync-ntfy h6,#ot-sync-ntfy p,#ot-sync-ntfy img,#ot-sync-ntfy svg,#ot-sync-ntfy button,#ot-sync-ntfy section,#ot-sync-ntfy a,#ot-sync-ntfy label,#ot-sync-ntfy input,#ot-sync-ntfy ul,#ot-sync-ntfy li,#ot-sync-ntfy nav,#ot-sync-ntfy table,#ot-sync-ntfy thead,#ot-sync-ntfy tr,#ot-sync-ntfy td,#ot-sync-ntfy tbody,#ot-sync-ntfy .ot-main-content,#ot-sync-ntfy .ot-toggle,#ot-sync-ntfy #ot-content,#ot-sync-ntfy #ot-pc-content,#ot-sync-ntfy .checkbox{font-family:inherit;font-weight:normal;-webkit-font-smoothing:auto;letter-spacing:normal;line-height:normal;padding:0;margin:0;height:auto;min-height:0;max-height:none;width:auto;min-width:0;max-width:none;border-radius:0;border:none;clear:none;float:none;position:static;bottom:auto;left:auto;right:auto;top:auto;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;white-space:normal;background:none;overflow:visible;vertical-align:baseline;visibility:visible;z-index:auto;box-shadow:none}#onetrust-banner-sdk label:before,#onetrust-banner-sdk label:after,#onetrust-banner-sdk .checkbox:after,#onetrust-banner-sdk .checkbox:before,#onetrust-pc-sdk label:before,#onetrust-pc-sdk label:afte ...
# #onetrust-banner-sdk .ot-sdk-container,#onetrust-pc-sdk .ot-sdk-container,#ot-sdk-cookie-policy .ot-sdk-container{position:relative;width:100%;max-width:100%;margin:0 auto;padding:0 20px;box-sizing:border-box}#onetrust-banner-sdk .ot-sdk-column,#onetrust-banner-sdk .ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-column,#onetrust-pc-sdk .ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-column,#ot-sdk-cookie-policy .ot-sdk-columns{width:100%;float:left;box-sizing:border-box;padding:0;display:initial}@media (min-width: 400px){#onetrust-banner-sdk .ot-sdk-container,#onetrust-pc-sdk .ot-sdk-container,#ot-sdk-cookie-policy .ot-sdk-container{width:90%;padding:0}}@media (min-width: 550px){#onetrust-banner-sdk .ot-sdk-container,#onetrust-pc-sdk .ot-sdk-container,#ot-sdk-cookie-policy .ot-sdk-container{width:100%}#onetrust-banner-sdk .ot-sdk-column,#onetrust-banner-sdk .ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-column,#onetrust-pc-sdk .ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-column,#ot-sdk-cookie-policy .ot-sdk-columns{margin-left:4%}#onetrust-banner-sdk .ot-sdk-column:first-child,#onetrust-banner-sdk .ot-sdk-columns:first-child,#onetrust-pc-sdk .ot-sdk-column:first-child,#onetrust-pc-sdk .ot-sdk-columns:first-child,#ot-sdk-cookie-policy .ot-sdk-column:first-child,#ot-sdk-cookie-policy .ot-sdk-columns:first-child{margin-left:0}#onetrust-banner-sdk .ot-sdk-one.ot-sdk-column,#onetrust-banner-sdk .ot-sdk-one.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-one.ot-sdk-column,#onetrust-pc-sdk .ot-sdk-one.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-one.ot-sdk-column,#ot-sdk-cookie-policy .ot-sdk-one.ot-sdk-columns{width:4.66666666667%}#onetrust-banner-sdk .ot-sdk-two.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-two.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-two.ot-sdk-columns{width:13.3333333333%}#onetrust-banner-sdk .ot-sdk-three.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-three.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-three.ot-sdk-columns{width:22%}#onetrust-banner-sdk .ot-sdk-four.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-four.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-four.ot-sdk-columns{width:30.6666666667%}#onetrust-banner-sdk .ot-sdk-five.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-five.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-five.ot-sdk-columns{width:39.3333333333%}#onetrust-banner-sdk .ot-sdk-six.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-six.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-six.ot-sdk-columns{width:48%}#onetrust-banner-sdk .ot-sdk-seven.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-seven.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-seven.ot-sdk-columns{width:56.6666666667%}#onetrust-banner-sdk .ot-sdk-eight.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-eight.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-eight.ot-sdk-columns{width:65.3333333333%}#onetrust-banner-sdk .ot-sdk-nine.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-nine.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-nine.ot-sdk-columns{width:74%}#onetrust-banner-sdk .ot-sdk-ten.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-ten.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-ten.ot-sdk-columns{width:82.6666666667%}#onetrust-banner-sdk .ot-sdk-eleven.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-eleven.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-eleven.ot-sdk-columns{width:91.3333333333%}#onetrust-banner-sdk .ot-sdk-twelve.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-twelve.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-twelve.ot-sdk-columns{width:100%;margin-left:0}#onetrust-banner-sdk .ot-sdk-one-third.ot-sdk-column,#onetrust-pc-sdk .ot-sdk-one-third.ot-sdk-column,#ot-sdk-cookie-policy .ot-sdk-one-third.ot-sdk-column{width:30.6666666667%}#onetrust-banner-sdk .ot-sdk-two-thirds.ot-sdk-column,#onetrust-pc-sdk .ot-sdk-two-thirds.ot-sdk-column,#ot-sdk-cookie-policy .ot-sdk-two-thirds.ot-sdk-column{width:65.3333333333%}#onetrust-banner-sdk .ot-sdk-one-half.ot-sdk-column,#onetrust-pc-sdk .ot-sdk-one-half.ot-sdk-column,#ot-sdk-cookie-policy .ot-sdk-one-half.ot-sdk-column{width:48%}#onetrust-banner-sdk .ot-sdk-offset-by-one.ot-sdk-c ...
# ...
# <script id="" type="text/javascript">var bk_addPageCtx;google_tag_manager["GTM-TB9QCTB"].macro(30)&&bk_addPageCtx("page_template",google_tag_manager["GTM-TB9QCTB"].macro(31));google_tag_manager["GTM-TB9QCTB"].macro(32)&&bk_addPageCtx("page_category",google_tag_manager["GTM-TB9QCTB"].macro(33));google_tag_manager["GTM-TB9QCTB"].macro(34)&&bk_addPageCtx("page_subcategory",google_tag_manager["GTM-TB9QCTB"].macro(35));google_tag_manager["GTM-TB9QCTB"].macro(36)&&bk_addPageCtx("symbol_assetClass",google_tag_manager["GTM-TB9QCTB"].macro(37));google_tag_manager["GTM-TB9QCTB"].macro(38)&&bk_addPageCtx("symbol_industry",google_tag_manager["GTM-TB9QCTB"].macro(39));google_tag_manager["GTM-TB9QCTB"].macro(40)&&bk_addPageCtx("taxonomy_solutions",google_tag_manager["GTM-TB9QCTB"].macro(41));
# google_tag_manager["GTM-TB9QCTB"].macro(42)&&bk_addPageCtx("taxonomy_topics",google_tag_manager["GTM-TB9QCTB"].macro(43));google_tag_manager["GTM-TB9QCTB"].macro(44)&&bk_addPageCtx("taxonomy_audiences",google_tag_manager["GTM-TB9QCTB"].macro(45));if(google_tag_manager["GTM-TB9QCTB"].macro(46)){var persona=google_tag_manager["GTM-TB9QCTB"].macro(47),bkPersona=persona.replace(/\s+/g,"");bk_addPageCtx("personas",bkPersona)}bk_doJSTag(31843,1);</script>
# <iframe id="_hjRemoteVarsFrame" name="_hjRemoteVarsFrame" src="https://vars.hotjar.com/box-0004cb77850b00d4aa7e1e08ff61e8f0.html" style="display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;" title="_hjRemoteVarsFrame"></iframe><div id="mktoStyleLoaded" style="display: none; border-top-color: rgb(18, 52, 86);"></div><form __biza="WJ__" __bizdiag="400165713" class="mktoForm mktoHasWidth mktoLayoutLeft" data-formid="2021" novalidate="novalidate" style="display: block; font-family: inherit; font-size: 13px; color: rgb(51, 51, 51); visibility: hidden; position: absolute; top: -500px; left: -1000px; width: 785px;"></form><iframe id="MktoForms2XDIframe" name="mktoFormsXDIframe0.8976854694905644" src="https://nd.nasdaq.com/index.php/form/XDFrame" style="display: none;"></iframe><script src="https://tags.bluekai.com/site/3396?ret=js&amp;jscb=moatBK3396_83756997" type="text/javascript"></script><iframe id="_hjSafeContext_44600866" src="about:blank" style="display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;"></iframe><div id="onetrust-consent-sdk"><div class="onetrust-pc-dark-filter ot-hide ot-fade-in"></div><div aria-labelledby="ot-pc-title" aria-modal="true" class="otPcCenter ot-hide ot-fade-in" id="onetrust-pc-sdk" lang="en" role="alertdialog"><!-- Close Button --><div class="ot-pc-header"><!-- Logo Tag --><div aria-label="Company Logo" class="ot-pc-logo" role="img" style='background-image: url("https://cdn.cookielaw.org/logos/static/ot_logo.png");
#                     background-position: left'></div><button aria-label="Close" class="ot-close-icon" id="close-pc-btn-handler"></button></div><!-- Close Button --><div class="ot-pc-scrollbar" id="ot-pc-content"><h3 id="ot-pc-title">Privacy Preference Center</h3><div id="ot-pc-desc">When you visit any website, it may store or retrieve information on your browser, mostly in the form of cookies. This information might be about you, your preferences or your device and is mostly used to make the site work as you expect it to. The information does not usually directly identify you, but it can give you a more personalized web experience. Because we respect your right to privacy, you can choose not to allow some types of cookies. Click on the different category headings to find out more and change our default settings. However, blocking some types of cookies may impact your experience of the site and the services we are able to offer.
#                 <br/><a aria-label="More information about your privacy, opens in a new tab" class="privacy-notice-link" href="https://cookiepedia.co.uk/giving-consent-to-cookies" rel="noopener" target="_blank">More information</a></div><button id="accept-recommended-btn-handler">Allow All</button><section class="ot-sdk-row ot-cat-grp"><h3 id="ot-category-title"> Manage Consent Preferences</h3><div class="ot-accordion-layout ot-cat-item" data-optanongroupid="C0004"><button aria-controls="ot-desc-id-C0004" aria-expanded="false" aria-labelledby="ot-header-id-C0004" ot-accordion="true"></button><!-- Accordion header --><div class="ot-acc-hdr"><div class="ot-plus-minus"><span></span><span></span></div><h4 class="ot-cat-header" id="ot-header-id-C0004">Targeting Cookies</h4><div class="ot-tgl"><input aria-checked="false" aria-labelledby="ot-header-id-C0004" class="category-switch-handler" data-optanongroupid="C0004" id="ot-group-id-C0004" name="ot-group-id-C0004" role="switch" type="checkbox"/> <label class="ot-switch" for="ot-group-id-C0004"><span class="ot-switch-nob"></span> <span class="ot-label-txt">Targeting Cookies</span></label> </div></div><!-- accordion detail --><div class="ot-acc-grpcntr ot-acc-txt"><p class="ot-acc-grpdesc ot-category-desc" id="ot-desc-id-C0004">These cookies may be set through our site by our advertising partners. They may be used by those companies to build a profile of your interests and show you relevant adverts on other sites.    They do not store directly personal information, but are based on uniquely identifying your browser and internet device. If you do not allow these cookies, you will experience less targeted advertising.</p></div></div><div class="ot-accordion-layout ot-cat-item" data-optanongroupid="C0001"><button aria-controls="ot-desc-id-C0001" aria-expanded="false" aria-labelledby="ot-header-id-C0001" ot-accordion="true"></button><!-- Accordion header --><div class="ot-acc-hdr ot-always-active-group"><div class="ot-plus-minus"><span></span><span></span></div><h4 class="ot-cat-header" id="ot-header-id-C0001">Strictly Necessary Cookies</h4><div class="ot-always-active">Always Active</div></div><!-- accordion detail --><div class="ot-acc-grpcntr ot-acc-txt"><p class="ot-acc-grpdesc ot-category-desc" id="ot-desc-id-C0001">These cookies are necessary for the website to function and cannot be switched off in our systems. They are usually only set in response to actions made by you which amount to a request for services, such as setting your privacy preferences, logging in or filling in forms.    You can set your browser to block or alert you about these cookies, but some parts of the site will not then work. These cookies do not store any personally identifiable information.</p></div></div><div class="ot-accordion-layout ot-cat-item" data-optanongroupid="C0003"><button aria-controls="ot-desc-id-C0003" aria-expanded="false" aria-labelledby="ot-header-id-C0003" ot-accordion="true"></button><!-- Accordion header --><div class="ot-acc-hdr"><div class="ot-plus-minus"><span></span><span></span></div><h4 class="ot-cat-header" id="ot-header-id-C0003">Functional Cookies</h4><div class="ot-tgl"><input aria-checked="false" aria-labelledby="ot-header-id-C0003" class="category-switch-handler" data-optanongroupid="C0003" id="ot-group-id-C0003" name="ot-group-id-C0003" role="switch" type="checkbox"/> <label class="ot-switch" for="ot-group-id-C0003"><span class="ot-switch-nob"></span> <span class="ot-label-txt">Functional Cookies</span></label> </div></div><!-- accordion detail --><div class="ot-acc-grpcntr ot-acc-txt"><p class="ot-acc-grpdesc ot-category-desc" id="ot-desc-id-C0003">These cookies enable the website to provide enhanced functionality and personalisation. They may be set by us or by third party providers whose services we have added to our pages.    If you do not allow these cookies then some or all of these services may not function properly.</p></div></div><div class="ot-accordion-layout ot-c ...
#                     l-21.409-21.416C323.432,3.521,314.817,0,304.637,0s-18.791,3.521-25.841,10.561L92.649,196.425
#                     c-7.044,7.043-10.566,15.656-10.566,25.841s3.521,18.791,10.566,25.837l186.146,185.864c7.05,7.043,15.66,10.564,25.841,10.564
#                     s18.795-3.521,25.834-10.564l21.409-21.412c7.05-7.039,10.567-15.604,10.567-25.697c0-10.085-3.518-18.746-10.567-25.978
#                     L213.13,222.409z" fill="#656565"></path></g></svg></button> <span>Performance Cookies</span></h3><div class="ot-lst-subhdr"><div class="ot-search-cntr"><p class="ot-scrn-rdr" role="status"></p><label class="ot-scrn-rdr" for="vendor-search-handler">Vendor Search</label> <input class="js-bound" id="vendor-search-handler" name="vendor-search-handler" placeholder="Search..." type="text"/> <svg viewbox="0 -30 110 110" x="0px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px"><title>Search Icon</title><path d="M55.146,51.887L41.588,37.786c3.486-4.144,5.396-9.358,5.396-14.786c0-12.682-10.318-23-23-23s-23,10.318-23,23
#             s10.318,23,23,23c4.761,0,9.298-1.436,13.177-4.162l13.661,14.208c0.571,0.593,1.339,0.92,2.162,0.92
#             c0.779,0,1.518-0.297,2.079-0.837C56.255,54.982,56.293,53.08,55.146,51.887z M23.984,6c9.374,0,17,7.626,17,17s-7.626,17-17,17
#             s-17-7.626-17-17S14.61,6,23.984,6z" fill="#2e3644"></path></svg></div><div class="ot-fltr-cntr"><button aria-haspopup="true" aria-label="Filter" id="filter-btn-handler"><svg aria-hidden="true" role="presentation" viewbox="0 0 402.577 402.577" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px"><title>Filter Icon</title><g><path d="M400.858,11.427c-3.241-7.421-8.85-11.132-16.854-11.136H18.564c-7.993,0-13.61,3.715-16.846,11.136
#       c-3.234,7.801-1.903,14.467,3.999,19.985l140.757,140.753v138.755c0,4.955,1.809,9.232,5.424,12.854l73.085,73.083
#       c3.429,3.614,7.71,5.428,12.851,5.428c2.282,0,4.66-0.479,7.135-1.43c7.426-3.238,11.14-8.851,11.14-16.845V172.166L396.861,31.413
#       C402.765,25.895,404.093,19.231,400.858,11.427z" fill="#fff"></path></g></svg></button></div><div id="ot-anchor"></div><section id="ot-fltr-modal"><div id="ot-fltr-cnt"><button id="clear-filters-handler">Clear</button><div class="ot-fltr-scrlcnt ot-pc-scrollbar"><div class="ot-fltr-opts"><div class="ot-fltr-opt"><div class="ot-chkbox"><input aria-checked="false" class="category-filter-handler" id="chkbox-id" type="checkbox"/> <label for="chkbox-id"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div></div></div><div class="ot-fltr-btns"><button id="filter-apply-handler">Apply</button> <button id="filter-cancel-handler">Cancel</button></div></div></div></section></div></div><section class="ot-host-cnt ot-pc-scrollbar" id="ot-lst-cnt"><div id="ot-sel-blk"><div class="ot-sel-all"><div class="ot-sel-all-hdr"><span class="ot-consent-hdr">Consent</span> <span class="ot-li-hdr">Leg.Interest</span></div><div class="ot-sel-all-chkbox"><div class="ot-chkbox" id="ot-selall-hostcntr"><input aria-checked="false" id="select-all-hosts-groups-handler" type="checkbox"/> <label for="select-all-hosts-groups-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div><div class="ot-chkbox" id="ot-selall-vencntr"><input aria-checked="false" id="select-all-vendor-groups-handler" type="checkbox"/> <label for="select-all-vendor-groups-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div><div class="ot-chkbox" id="ot-selall-licntr"><input aria-checked="false" id="select-all-vendor-leg-handler" type="checkbox"/> <label for="select-all-vendor-leg-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div></div></div></div><div class="ot-sdk-row"><div class="ot-sdk-column"></div></div></section></section><div class="ot-pc-footer"><div class="ot-btn-container"> <button class="save-preference-btn-handler onetrust-close-btn-handler">Confirm My Choices</button></div><!-- Footer logo --><div class="ot-pc-footer-logo"><a aria-label="Powered by OneTrust Opens in a new Tab" href="https://www.onetrust.com/products/cookie-consent/" rel="noopener noreferrer" style='background-image: url("https://cdn.cookielaw.org/logos/static/poweredBy_ot_logo.svg")' target="_blank"></a></div></div><!-- Cookie subgroup container --><!-- Vendor list link --><!-- Cookie lost link --><!-- Toggle HTML element --><!-- Checkbox HTML --><!-- plus minus--><!-- Arrow SVG element --><!-- Accordion basic element --><span aria-atomic="true" aria-live="polite" class="ot-scrn-rdr"></span><iframe aria-hidden="true" class="ot-text-resize" style="position:absolute;top:-50000px;width:100em;" title="onetrust-text-resize"></iframe></div><div class="otFlat bottom ot-wo-title" id="onetrust-banner-sdk" style="bottom: -99px; animation-name: slide-down-custom; animation-duration: 1000ms; animation-fill-mode: forwards; animation-timing-function: ease-out;"><div aria-describedby="onetrust-policy-text" role="alertdialog"><div class="ot-sdk-container"><div class="ot-sdk-row"><div class="ot-sdk-eight ot-sdk-columns" id="onetrust-group-container"><div class="banner_logo"></div><div id="onetrust-policy"><p id="onetrust-policy-text">By clicking “Accept All Cookies”, you agree to the storing of cookies on your device to enhance site navigation, analyze site usage, and assist in our marketing efforts. </p></div></div><div class="ot-sdk-three ot-sdk-columns" id="onetrust-button-group-parent"><div id="onetrust-button-group"><button class="cookie-setting-link" id="onetrust-pc-btn-handler">Cookies Settings</button> <button id="onetrust-accept-btn-handler">Accept All Cookies</button></div></div></div></div><!-- Close Button --><div id="onetrust-close-btn-container"><button aria-label="Close" class="onetrust-close-btn-handler onetrust-close-btn-ui banner-close-button ot-close-icon"></button></div>< ...

# %%
# for thing in soup.find(class='historical-data__table-body').find_all('tr class'):
#     print(thing['th class'])

soup.find_all(attrs={'class':'historical-data__cell','scope':'row'})
# Out:
# [<th class="historical-data__cell" scope="row">07/29/2022</th>,
#  <td class="historical-data__cell" scope="row">527.1</td>,
#  <td class="historical-data__cell" scope="row">307</td>,
#  <td class="historical-data__cell" scope="row">534.6</td>,
#  <td class="historical-data__cell" scope="row">535.1</td>,
#  <td class="historical-data__cell" scope="row">523.1</td>,
#  <th class="historical-data__cell" scope="row">07/28/2022</th>,
#  <td class="historical-data__cell" scope="row">536.7</td>,
#  <td class="historical-data__cell" scope="row">371</td>,
#  <td class="historical-data__cell" scope="row">555.2</td>,
#  <td class="historical-data__cell" scope="row">559.2</td>,
#  <td class="historical-data__cell" scope="row">531</td>,
#  <th class="historical-data__cell" scope="row">07/27/2022</th>,
#  <td class="historical-data__cell" scope="row">555.2</td>,
#  <td class="historical-data__cell" scope="row">201</td>,
#  <td class="historical-data__cell" scope="row">549</td>,
#  <td class="historical-data__cell" scope="row">561.6</td>,
#  <td class="historical-data__cell" scope="row">542</td>,
#  <th class="historical-data__cell" scope="row">07/26/2022</th>,
#  <td class="historical-data__cell" scope="row">556.6</td>,
#  <td class="historical-data__cell" scope="row">374</td>,
#  <td class="historical-data__cell" scope="row">565.3</td>,
#  <td class="historical-data__cell" scope="row">574.5</td>,
#  <td class="historical-data__cell" scope="row">531.2</td>,
#  <th class="historical-data__cell" scope="row">07/25/2022</th>,
#  <td class="historical-data__cell" scope="row">572.2</td>,
#  <td class="historical-data__cell" scope="row">280</td>,
#  <td class="historical-data__cell" scope="row">583</td>,
#  <td class="historical-data__cell" scope="row">583</td>,
#  <td class="historical-data__cell" scope="row">554.3</td>,
#  <th class="historical-data__cell" scope="row">07/22/2022</th>,
#  <td class="historical-data__cell" scope="row">585.3</td>,
#  <td class="historical-data__cell" scope="row">256</td>,
#  <td class="historical-data__cell" scope="row">617</td>,
#  <td class="historical-data__cell" scope="row">617</td>,
#  <td class="historical-data__cell" scope="row">576.2</td>,
#  <th class="historical-data__cell" scope="row">07/21/2022</th>,
#  <td class="historical-data__cell" scope="row">623.2</td>,
#  <td class="historical-data__cell" scope="row">243</td>,
#  <td class="historical-data__cell" scope="row">623.8</td>,
#  <td class="historical-data__cell" scope="row">630</td>,
#  <td class="historical-data__cell" scope="row">599.4</td>,
#  <th class="historical-data__cell" scope="row">07/20/2022</th>,
#  <td class="historical-data__cell" scope="row">631.6</td>,
#  <td class="historical-data__cell" scope="row">127</td>,
#  <td class="historical-data__cell" scope="row">648.1</td>,
#  <td class="historical-data__cell" scope="row">648.5</td>,
#  <td class="historical-data__cell" scope="row">623.1</td>,
#  <th class="historical-data__cell" scope="row">07/19/2022</th>,
#  <td class="historical-data__cell" scope="row">646.3</td>,
#  <td class="historical-data__cell" scope="row">147</td>,
#  <td class="historical-data__cell" scope="row">642.1</td>,
#  <td class="historical-data__cell" scope="row">648.7</td>,
#  <td class="historical-data__cell" scope="row">628.2</td>,
#  <th class="historical-data__cell" scope="row">07/18/2022</th>,
#  <td class="historical-data__cell" scope="row">640.8</td>,
#  <td class="historical-data__cell" scope="row">176</td>,
#  <td class="historical-data__cell" scope="row">655</td>,
#  <td class="historical-data__cell" scope="row">659.9</td>,
#  <td class="historical-data__cell" scope="row">626.2</td>,
#  <th class="historical-data__cell" scope="row">07/15/2022</th>,
#  <td class="historical-data__cell" scope="row">648.8</td>,
#  <td class="historical-data__cell" scope="row">187</td>,
#  <td class="historical-data__cell" scope="row">642</td>,
#  <td class="historical-data__cell" scope="row">650</td>,
#  <td class="historical-data__cell" scope="row">618.1</td>,
#  <th class="historical-data__cell" scope="row">07/14/2022</th>,
#  <td class="historical-data__cell" scope="row">646</td>,
#  <td class="historical-data__cell" scope="row">277</td>,
#  <td class="historical-data__cell" scope="row">660.6</td>,
#  <td class="historical-data__cell" scope="row">664.2</td>,
#  <td class="historical-data__cell" scope="row">634.3</td>,
#  <th class="historical-data__cell" scope="row">07/13/2022</th>,
#  <td class="historical-data__cell" scope="row">683.3</td>,
#  <td class="historical-data__cell" scope="row">121</td>,
#  <td class="historical-data__cell" scope="row">670.2</td>,
#  <td class="historical-data__cell" scope="row">695</td>,
#  <td class="historical-data__cell" scope="row">670.2</td>,
#  <th class="historical-data__cell" scope="row">07/12/2022</th>,
#  <td class="historical-data__cell" scope="row">679.3</td>,
#  <td class="historical-data__cell" scope="row">125</td>,
#  <td class="historical-data__cell" scope="row">677.7</td>,
#  <td class="historical-data__cell" scope="row">700</td>,
#  <td class="historical-data__cell" scope="row">671.5</td>,
#  <th class="historical-data__cell" scope="row">07/11/2022</th>,
#  <td class="historical-data__cell" scope="row">696.8</td>,
#  <td class="historical-data__cell" scope="row">199</td>,
#  <td class="historical-data__cell" scope="row">690</td>,
#  <td class="historical-data__cell" scope="row">707</td>,
#  <td class="historical-data__cell" scope="row">658.1</td>,
#  <th class="historical-data__cell" scope="row">07/08/2022</th>,
#  <td class="historical-data__cell" scope="row">707</td>,
#  <td class="historical-data__cell" scope="row">323</td>,
#  <td class="historical-data__cell" scope="row">730</td>,
#  <td class="historical-data__cell" scope="row">749.5</td>,
#  <td class="historical-data__cell" scope="row">693.4</td>,
#  <th class="historical-data__cell" scope="row">07/07/2022</th>,
#  <td class="historical-data__cell" scope="row">725.9</td>,
#  <td class="historical-data__cell" scope="row">404</td>,
#  <td class="historical-data__cell" scope="row">686</td>,
#  <td class="historical-data__cell" scope="row">735.4</td>,
#  <td class="historical-data__cell" scope="row">686</td>,
#  <th class="historical-data__cell" scope="row">07/06/2022</th>,
#  <td class="historical-data__cell" scope="row">686.5</td>,
#  <td class="historical-data__cell" scope="row">217</td>,
#  <td class="historical-data__cell" scope="row">644.7</td>,
#  <td class="historical-data__cell" scope="row">689.1</td>,
#  <td class="historical-data__cell" scope="row">624.4</td>]

# %%
import sqlite3
from sqlite3 import Error

# %%
conn = None
try:
    conn = sqlite3.connect('elf.db')
except Error as e:
    print(e)

# %%
#Consumer price index
df2 = pd.read_csv('https://www.econdb.com/api/series/CPIUS/?format=csv',index_col='Date', parse_dates=['Date'])

# %%
df2.to_sql(name='Consumer_Price_Index', con=conn)

# %%
df2.info
# Out:
# <bound method DataFrame.info of              CPIUS
# Date
# 1947-01-01   21.48
# 1947-02-01   21.62
# 1947-03-01   22.00
# 1947-04-01   22.00
# 1947-05-01   21.95
# ...            ...
# 2022-02-01  284.20
# 2022-03-01  287.70
# 2022-04-01  288.70
# 2022-05-01  291.50
# 2022-06-01  295.30
#
# [906 rows x 1 columns]>

# %%
#Unemployment
df3 = pd.read_csv('https://www.econdb.com/api/series/URATEUS/?format=csv',index_col='Date', parse_dates=['Date'])
df3.to_sql(name='Unemployment', con=conn)

# %%
df3.info
# Out:
# <bound method DataFrame.info of             URATEUS
# Date
# 1948-01-01      3.4
# 1948-02-01      3.8
# 1948-03-01      4.0
# 1948-04-01      3.9
# 1948-05-01      3.5
# ...             ...
# 2022-02-01      3.8
# 2022-03-01      3.6
# 2022-04-01      3.6
# 2022-05-01      3.6
# 2022-06-01      3.6
#
# [894 rows x 1 columns]>

# %%
#Retail Trade
df4 = pd.read_csv('https://www.econdb.com/api/series/RETAUS/?format=csv', index_col='Date', parse_dates=['Date'])
df4.to_sql(name='Retail_Trade', con=conn)

# %%
df4.info
# Out:
# <bound method DataFrame.info of             RETAUS
# Date
# 1992-01-01  146925
# 1992-02-01  147223
# 1992-03-01  146805
# 1992-04-01  148032
# 1992-05-01  149010
# ...            ...
# 2022-02-01  581768
# 2022-03-01  587570
# 2022-04-01  590238
# 2022-05-01  588635
# 2022-06-01  594499
#
# [366 rows x 1 columns]>

# %%
df5 = pd.read_csv('https://www.econdb.com/api/series/HOUUS/?format=csv',index_col='Date', parse_dates=['Date'])
df5.to_sql(name='Housing_Price', con=conn)

# %%
df5.info
# Out:
# <bound method DataFrame.info of             HOUUS
# Date
# 1991-01-01  100.0
# 1991-02-01  100.5
# 1991-03-01  100.5
# 1991-04-01  100.3
# 1991-05-01  100.4
# ...           ...
# 2022-01-01  373.6
# 2022-02-01  380.9
# 2022-03-01  386.7
# 2022-04-01  392.7
# 2022-05-01  398.0
#
# [377 rows x 1 columns]>

# %%
#hourly wage manufacturing
df6 = pd.read_csv('https://www.econdb.com/api/series/WAGEMANUS/?format=csv',index_col='Date', parse_dates=['Date'])
df6.to_sql(name='Hourly_Wage_Manuf', con=conn)

# %%
df6.info
# Out:
# <bound method DataFrame.info of             WAGEMANUS
# Date
# 2014-07-01      24.48
# 2014-08-01      24.55
# 2014-09-01      24.56
# 2014-10-01      24.58
# 2014-11-01      24.65
# ...               ...
# 2022-02-01      31.60
# 2022-03-01      31.75
# 2022-04-01      31.86
# 2022-05-01      31.98
# 2022-06-01      32.08
#
# [96 rows x 1 columns]>

# %%
#interest rates
df7 = pd.read_csv('https://www.econdb.com/api/series/POLIRUS/?format=csv',index_col='Date', parse_dates=['Date'])
df7.to_sql(name='Interest_Rates', con=conn)

# %%
df7.info
# Out:
# <bound method DataFrame.info of             POLIRUS
# Date
# 1954-07-01     0.80
# 1954-08-01     1.22
# 1954-09-01     1.07
# 1954-10-01     0.85
# 1954-11-01     0.83
# ...             ...
# 2022-02-01     0.08
# 2022-03-01     0.20
# 2022-04-01     0.33
# 2022-05-01     0.77
# 2022-06-01     1.21
#
# [816 rows x 1 columns]>

# %%
#sentiment index
df8 = pd.read_csv('https://www.econdb.com/api/series/SENTUS/?format=csv',index_col='Date', parse_dates=['Date'])
df8.to_sql(name='Sentiment_Index', con=conn)
#stock exchange index
df9 = pd.read_csv('https://www.econdb.com/api/series/SEIUS/?format=csv',index_col='Date', parse_dates=['Date'])
df9.to_sql(name='Stock_Exchange', con=conn)
#change in inventories
df10 = pd.read_csv('https://www.econdb.com/api/series/CIUS/?format=csv',index_col='Date', parse_dates=['Date'])
df10.to_sql(name='Inventory_Change', con=conn)
#money supply
df11 = pd.read_csv('https://www.econdb.com/api/series/M3US/?format=csv',index_col='Date', parse_dates=['Date'])
df11.to_sql(name='Money_Supply', con=conn)
#electricity production
df12 = pd.read_csv('https://www.econdb.com/api/series/ELEUS/?format=csv',index_col='Date', parse_dates=['Date'])
df12.to_sql(name='Elect_Prod', con=conn)
#oil production
df13 = pd.read_csv('https://www.econdb.com/api/series/OILPRODUS/?format=csv',index_col='Date', parse_dates=['Date'])
df13.to_sql(name='Oil_Prod', con=conn)

# %%
#industrial production
df14=pd.read_csv('https://www.econdb.com/api/series/IPUS/?format=csv',index_col='Date', parse_dates=['Date'])
df14.to_sql(name='Industrial_Production', con=conn)
#real gross domestic product
df15=pd.read_csv('https://www.econdb.com/api/series/RGDPUS/?format=csv',index_col='Date', parse_dates=['Date'])
df15.to_sql(name='Real_GDP', con=conn)
#Producer price Index
df16=pd.read_csv('https://www.econdb.com/api/series/PPIUS/?format=csv',index_col='Date', parse_dates=['Date'])
df16.to_sql(name='Producer_Price_Index', con=conn)
#Government Debt
df17=pd.read_csv('https://www.econdb.com/api/series/GDEBTUS/?format=csv',index_col='Date', parse_dates=['Date'])
df17.to_sql(name='Govt_Debt', con=conn)
#Export Goods
df18=pd.read_csv('https://www.econdb.com/api/series/EXPUS/?format=csv',index_col='Date', parse_dates=['Date'])
df18.to_sql(name='Export_Goods_Services', con=conn)
#Import Goods
df19=pd.read_csv('https://www.econdb.com/api/series/IMPUS/?format=csv',index_col='Date', parse_dates=['Date'])
df19.to_sql(name='Import_Goods_Services', con=conn)
#Job Vacancy Rate
df20=pd.read_csv('https://www.econdb.com/api/series/JVRUS/?format=csv',index_col='Date', parse_dates=['Date'])
df20.to_sql(name='Job_Vacancy_Rate', con=conn)
#General Govt Total Expenditure
df21=pd.read_csv('https://www.econdb.com/api/series/GSPEUS/?format=csv',index_col='Date', parse_dates=['Date'])
df21.to_sql(name='Gen_Govt_Tot_Expenditure', con=conn)
#Gasoline Demand
df23=pd.read_csv('https://www.econdb.com/api/series/GASODEMUS/?format=csv',index_col='Date', parse_dates=['Date'])
df23.to_sql(name='Gasoline_Demand', con=conn)
#Oil Demand
df24=pd.read_csv('https://www.econdb.com/api/series/OILDEMUS/?format=csv',index_col='Date', parse_dates=['Date'])
df24.to_sql(name='Oil_Demand', con=conn)
#Gas Demand
df25=pd.read_csv('https://www.econdb.com/api/series/GASDEMUS/?format=csv',index_col='Date', parse_dates=['Date'])
df25.to_sql(name='Gas_Demand', con=conn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-dc71f6e8dde4> in <module>
#      25 #Money Supply
#      26 df22=pd.read_csv('https://www.econdb.com/api/series/M3US/?format=csv',index_col='Date', parse_dates=['Date'])
# ---> 27 df22.to_sql(name='Money_Supply', con=conn)
#      28 #Gasoline Demand
#      29 df23=pd.read_csv('https://www.econdb.com/api/series/GASODEMUS/?format=csv',index_col='Date', parse_dates=['Date'])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1825             dtype=dtype,
#    1826         )
# -> 1827         table.create()
#    1828         table.insert(chunksize, method)
#    1829
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in create(self)
#     721         if self.exists():
#     722             if self.if_exists == "fail":
# --> 723                 raise ValueError(f"Table '{self.name}' already exists.")
#     724             elif self.if_exists == "replace":
#     725                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'Money_Supply' already exists.

# %%
#COVID
df26=pd.read_csv('https://api.covidactnow.org/v2/country/US.timeseries.csv?apiKey=9ea206e96d044285aeea6455fe2144cb')
df26.to_sql(name='COVID', con=conn)

# %%
#Gasoline Demand
df23=pd.read_csv('https://www.econdb.com/api/series/GASODEMUS/?format=csv',index_col='Date', parse_dates=['Date'])
df23.to_sql(name='Gasoline_Demand', con=conn)
#Oil Demand
df24=pd.read_csv('https://www.econdb.com/api/series/OILDEMUS/?format=csv',index_col='Date', parse_dates=['Date'])
df24.to_sql(name='Oil_Demand', con=conn)
#Gas Demand
df25=pd.read_csv('https://www.econdb.com/api/series/GASDEMUS/?format=csv',index_col='Date', parse_dates=['Date'])
df25.to_sql(name='Gas_Demand', con=conn)
